# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\windows\\Desktop\\Kings project\\HAR'

# %%
harData = pd.read_csv("a_data.csv")

# %%
len(harData)
# Out:
# 49159

# %%
harData.T
# Out:
#                  0             1             2             3      \
# Date        10/31/2018    10/31/2018    10/31/2018    10/31/2018
# Time      13:46:39:650  13:46:39:696  13:46:39:740  13:46:39:800
# Resistor       44.8276       44.8276       44.8276       44.8276
# RC                   0             0             0             0
# RR                  13            13            13            13
# VT             1.78632       1.78632       1.78632       1.78632
# V              23.2221       23.2221       23.2221       23.2221
# DTCY                33            33            33            33
# Target        Standing      Standing      Standing      Standing
#
#                  4             5             6             7      \
# Date        10/31/2018    10/31/2018    10/31/2018    10/31/2018
# Time      13:46:39:845  13:46:39:890  13:46:39:951  13:46:39:995
# Resistor       44.8276       44.8821       44.9914       45.1009
# ...

# %%
harData.head()
# Out:
#          Date          Time  Resistor  RC  RR        VT         V  DTCY  \
# 0  10/31/2018  13:46:39:650  44.82758   0  13  1.786316  23.22211    33
# 1  10/31/2018  13:46:39:696  44.82758   0  13  1.786316  23.22211    33
# 2  10/31/2018  13:46:39:740  44.82758   0  13  1.786316  23.22211    33
# 3  10/31/2018  13:46:39:800  44.82758   0  13  1.786316  23.22211    33
# 4  10/31/2018  13:46:39:845  44.82758   0  13  1.786316  23.22211    33
#
#      Target
# 0  Standing
# 1  Standing
# 2  Standing
# 3  Standing
# 4  Standing

# %%
harData.columns
# Out:
# Index(['Date', 'Time', 'Resistor', 'RC', 'RR', 'VT', 'V', 'DTCY', 'Target'], dtype='object')

# %%
# Try to rename some of the columns
#harData.columns = ['Date', 'Time', 'Resistor', 'RC', 'RR', 'VT', 'V', 'DTCY', 'myTarget']

# %%
#Explortion of the dataset
harData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49159 entries, 0 to 49158
# Data columns (total 9 columns):
# Date        49159 non-null object
# Time        49159 non-null object
# Resistor    49159 non-null float64
# RC          49159 non-null int64
# RR          49159 non-null int64
# VT          49159 non-null float64
# V           49159 non-null float64
# DTCY        49159 non-null int64
# Target      49159 non-null object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 3.4+ MB

# %%
harData.describe()
# Out:
#            Resistor            RC            RR            VT             V  \
# count  49159.000000  49159.000000  49159.000000  49159.000000  49159.000000
# mean      42.888814      7.938526     15.608210      1.568183     21.084288
# std        5.310733      5.059313      7.869147      2.381725     11.229385
# min       31.642750      0.000000     -1.000000     -0.703995     -6.335953
# 25%       43.803300      4.000000     12.000000      1.087627     15.302350
# 50%       45.320630      7.000000     13.000000      1.519215     20.252840
# 75%       46.153850     11.000000     20.000000      1.802528     26.773220
# max       50.426050     24.000000     40.000000     47.414100    110.950400
#
#                DTCY
# count  49159.000000
# mean      32.124453
# std       32.925070
# min     -333.000000
# 25%       28.000000
# 50%       33.000000
# 75%       42.000000
# max       90.000000

# %%
harData.Target = harData.Target.astype('category')

# %%
harData.head()
# Out:
#          Date          Time  Resistor  RC  RR        VT         V  DTCY  \
# 0  10/31/2018  13:46:39:650  44.82758   0  13  1.786316  23.22211    33
# 1  10/31/2018  13:46:39:696  44.82758   0  13  1.786316  23.22211    33
# 2  10/31/2018  13:46:39:740  44.82758   0  13  1.786316  23.22211    33
# 3  10/31/2018  13:46:39:800  44.82758   0  13  1.786316  23.22211    33
# 4  10/31/2018  13:46:39:845  44.82758   0  13  1.786316  23.22211    33
#
#      Target
# 0  Standing
# 1  Standing
# 2  Standing
# 3  Standing
# 4  Standing

# %%
harData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49159 entries, 0 to 49158
# Data columns (total 9 columns):
# Date        49159 non-null object
# Time        49159 non-null object
# Resistor    49159 non-null float64
# RC          49159 non-null int64
# RR          49159 non-null int64
# VT          49159 non-null float64
# V           49159 non-null float64
# DTCY        49159 non-null int64
# Target      49159 non-null category
# dtypes: category(1), float64(3), int64(3), object(2)
# memory usage: 3.0+ MB

# %%
# Accessing the uniq values in the catigorical cloumn
harData.Target.cat.categories
# Out:
# Index(['Hopping', 'Reading', 'Sitting', 'Standing', 'Walking'], dtype='object')

# %%
# Visualization
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("darkgrid")

# %%
# Jointplots
# Resistor	RC	RR	VT	V	DTCY
j = sns.jointplot(data=harData, x="V", y="VT")

# %%
# Resistor	RC	RR	VT	V	DTCY
j = sns.jointplot(data=harData, x="Resistor", y="V", kind='hex')

# %%
# hISTOGRam
# Resistor	RC	RR	VT	V	DTCY
h1 = sns.distplot(harData.Resistor)

# %%
# Resistor	RC	RR	VT	V	DTCY
h1 = sns.distplot(harData.RC)

# %%
# Resistor	RC	RR	VT	V	DTCY
h1 = sns.distplot(harData.RR)

# %%
# Resistor	RC	RR	VT	V	DTCY
h1 = sns.distplot(harData.VT)

# %%
# Resistor	RC	RR	VT	V	DTCY
h1 = sns.distplot(harData.V, bins=15)

# %%
# Resistor	RC	RR	VT	V	DTCY
h1 = sns.distplot(harData.DTCY)

# %%
print(harData.Target.unique())
print("----------------------------------------")
print(harData.Target.value_counts())
# Out:
# [Standing, Sitting, Walking, Reading, Hopping]
# Categories (5, object): [Standing, Sitting, Walking, Reading, Hopping]
# ----------------------------------------
# Standing    11990
# Sitting     11990
# Reading     10791
# Walking      9592
# Hopping      4796
# Name: Target, dtype: int64

# %%
sns.set(rc={'figure.figsize':(13,6)})
fig = sns.countplot(x = "Target" , data = harData)
plt.xlabel("Activity")
plt.ylabel("Count")
plt.title("Activity Count")
plt.grid(True)
plt.show(fig)

# %%
# Resistor	RC	RR	VT	V	DTCY
pd.crosstab(harData.RR, harData.Target, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow0_col0 {
#             background-color:  #fff600;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow0_col1 {
#             background-color:  #fff600;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow0_col2 {
#             background-color:  #ffee00;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow0_col3 {
#             background-color:  #ffef00;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow0_col4 {
#             background-color:  #ffee00;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow0_col5 {
#             background-color:  #fff200;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow1_col0 {
#             background-color:  #fffb00;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow1_col1 {
#             background-color:  #ffff00;
#         }    #T_45c3edd4_0742_11e9_a52d_10ddb1eab99drow1_col2 {
#             background-color:  #ffff00;
# ...

# %%
# Resistor	RC	RR	VT	V	DTCY
pd.crosstab(harData.DTCY, harData.Target, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_4a045776_0742_11e9_8908_10ddb1eab99drow0_col0 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow0_col1 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow0_col2 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow0_col3 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow0_col4 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow0_col5 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow1_col0 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow1_col1 {
#             background-color:  #ffff00;
#         }    #T_4a045776_0742_11e9_8908_10ddb1eab99drow1_col2 {
#             background-color:  #fffd00;
# ...

# %%
sns.set(rc={'figure.figsize':(10,5)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen"]
index = -1
for i in harData.columns[2:8]:
    index = index + 1
    fig = sns.kdeplot(harData[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig)

# %%
# Feature Scaling
# Pre-processing and data preparation to feed data into Artificial Neural Network.
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(harData.iloc[:,2:8])
mat_train = scaler.transform(harData.iloc[:,2:8])
print(mat_train)
# Out:
# [[0.70194428 0.         0.34146341 0.05175414 0.25201622 0.86524823]
#  [0.70194428 0.         0.34146341 0.05175414 0.25201622 0.86524823]
#  [0.70194428 0.         0.34146341 0.05175414 0.25201622 0.86524823]
#  ...
#  [0.71649391 0.79166667 0.51219512 0.05786218 0.40874673 0.90543735]
#  [0.71357749 0.79166667 0.51219512 0.05786218 0.40874673 0.90543735]
#  [0.71066373 0.79166667 0.51219512 0.05786218 0.40874673 0.90543735]]

# %%
# Standing, Sitting, Walking, Reading, Hopping
temp = []
for i in harData.Target:
    if i == "Standing": temp.append(0)
    if i == "Sitting": temp.append(1)
    if i == "Walking": temp.append(2)
    if i == "Reading": temp.append(3)
    if i == "Hopping": temp.append(4)
harData["n_Activity"] = temp

# %%
#harData

# %%
harData.drop(["Date", "Time", "Target"] , axis = 1 , inplace = True)

# %%
harData.head()
# Out:
#    Resistor  RC  RR        VT         V  DTCY  n_Activity
# 0  44.82758   0  13  1.786316  23.22211    33           0
# 1  44.82758   0  13  1.786316  23.22211    33           0
# 2  44.82758   0  13  1.786316  23.22211    33           0
# 3  44.82758   0  13  1.786316  23.22211    33           0
# 4  44.82758   0  13  1.786316  23.22211    33           0

# %%
x = harData.iloc[:, 0:6].values
y = harData.iloc[:, 6].values

# %%
# x
# y

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_y_1 = LabelEncoder()
y = labelencoder_y_1.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(x, y, test_size=0.25, random_state=101)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
trainX = sc.fit_transform(trainX)
testX = sc.fit_transform(testX)

# %%
print(trainX.shape , trainY.shape)
print(testX.shape , testY.shape)
# Out:
# (36869, 6) (36869,)
# (12290, 6) (12290,)

# %%
#Taking necessary callbacks of checkpointing and learning rate reducer.
filepath="HAR_weights.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint

lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
# Out:
# Using TensorFlow backend.

# %%
# Part two - Time for the ANN
# import the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout , BatchNormalization
from keras.utils import np_utils
from keras.optimizers import RMSprop, Adam
from keras import regularizers

# %%
# Initialize the ANN
model = Sequential()

# %%
# Adding the input layer and the first hidden layer
model.add(Dense(64, input_dim=trainX.shape[1], activation='relu', kernel_regularizer=regularizers.l1_l2(0.001)))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dense(196, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(6, activation='sigmoid'))

model.compile(optimizer = Adam(lr = 0.0005),loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 64)                448
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 196)               25284
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                6304
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 198
# ...
# Total params: 44,970
# ...

# %%
history = model.fit(trainX, trainY , epochs=25 , batch_size = 32 , validation_data=(testX, testY) , callbacks=[checkpoint,lr_reduce])
# Out:
# Train on 36869 samples, validate on 12290 samples
# Epoch 1/25
# 36736/36869 [============================>.] - ETA: 0s - loss: 0.6951 - acc: 0.7556
# Epoch 00001: val_acc improved from -inf to 0.82042, saving model to HAR_weights.hdf5
# 36869/36869 [==============================] - 4s 110us/step - loss: 0.6945 - acc: 0.7559 - val_loss: 0.5167 - val_acc: 0.8204
# Epoch 2/25
# 36864/36869 [============================>.] - ETA: 0s - loss: 0.4803 - acc: 0.8353
# Epoch 00002: val_acc improved from 0.82042 to 0.86648, saving model to HAR_weights.hdf5
# 36869/36869 [==============================] - 3s 92us/step - loss: 0.4804 - acc: 0.8352 - val_loss: 0.4163 - val_acc: 0.8665
# Epoch 3/25
# 36864/36869 [============================>.] - ETA: 0s - loss: 0.3959 - acc: 0.8666
# Epoch 00003: val_acc improved from 0.86648 to 0.87819, saving model to HAR_weights.hdf5
# ...

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 4
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 4
plt.plot(history.history['acc'], label="train_acc")
plt.plot(history.history['val_acc'], label="val_loss")
plt.plot(history.history['loss'], label="train_loss")
plt.plot(history.history['val_loss'], label="val_loss")
plt.title('Training Loss and Accuracy')
plt.ylabel('loss/accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper right')
plt.show()

# %%
# Evaluate the network
print("[INFO] evaluating network...")
from sklearn.metrics import classification_report , accuracy_score
from sklearn.metrics import confusion_matrix
model.load_weights("HAR_weights.hdf5")
y_pred = model.predict(testX)
y_pred = np.argmax(y_pred, axis = 1) 

cm = confusion_matrix(testY, y_pred)
print(cm)
# Out:
# [INFO] evaluating network...
# [[2971   31   19    0    0]
#  [  13 2934   18    0    0]
#  [  18   13 2362    0   13]
#  [   0    0    0 2696    0]
#  [  16    0   31    0 1155]]

# %%
print(classification_report(testY, y_pred))
'''

'''
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      3021
#           1       0.99      0.99      0.99      2965
#           2       0.97      0.98      0.98      2406
#           3       1.00      1.00      1.00      2696
#           4       0.99      0.96      0.97      1202
#
# avg / total       0.99      0.99      0.99     12290
# '\n\n'

# %%
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(10, 5))
plt.show()
